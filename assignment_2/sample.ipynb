# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path = '../samples/samples_5000x64x64x3.npz'

# Load the NPZ file
data = np.load(file_path)
array_names = data.files
array_names
# Out:
# ['arr_0']

# %%
images = data['arr_0']
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
indices = np.random.randint(0, len(images), 5)
for i, idx in enumerate(indices):
    axes[i].imshow(images[idx])
    axes[i].axis('off')
    axes[i].set_title(f'Image {i+1}')

plt.tight_layout()
plt.show()

# %%
file_path = '../samples/VIRTUAL_imagenet64_labeled.npz'

# Load the NPZ file
data = np.load(file_path)
array_names = data.files
array_names
# Out:
# ['mu', 'sigma', 'mu_s', 'sigma_s', 'mu_clip', 'sigma_clip', 'arr_0']

# %%
images = data['arr_0']
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
indices = np.random.randint(0, len(images), 5)
for i, idx in enumerate(indices):
    axes[i].imshow(images[idx])
    axes[i].axis('off')
    axes[i].set_title(f'Image {i+1}')

plt.tight_layout()
plt.show()

# %%
file_path = '../samples/biggan_deep_imagenet64.npz'

# Load the NPZ file
data = np.load(file_path)
array_names = data.files
array_names
# Out:
# ['z', 'arr_0', 'arr_1']

# %%
images = data['arr_0']
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
indices = np.random.randint(0, len(images), 5)
for i, idx in enumerate(indices):
    axes[i].imshow(images[idx])
    axes[i].axis('off')
    axes[i].set_title(f'Image {i+1}')

plt.tight_layout()
plt.show()

# %%
file_path = '../samples/samples_8x256x256x3.npz'

# Load the NPZ file
data = np.load(file_path)
array_names = data.files
array_names
# Out:
# ['arr_0']

# %%
images = data['arr_0']
fig, axes = plt.subplots(1, 5, figsize=(20, 4))
indices = np.random.randint(0, len(images), 5)
for i, idx in enumerate(indices):
    axes[i].imshow(images[idx])
    axes[i].axis('off')
    axes[i].set_title(f'Image {i+1}')

plt.tight_layout()
plt.show()
